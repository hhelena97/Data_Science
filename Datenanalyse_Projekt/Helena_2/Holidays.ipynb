# %%
import pandas as pd

# %%
neujahr = pd.DataFrame({
  'holiday': 'Neujahr',
  'ds': pd.to_datetime(['2016-01-01', '2017-01-01', '2018-01-01',
                        '2019-01-01', '2020-01-01', '2021-01-01', '2022-01-01']),
  'lower_window': -1,
  'upper_window': 0,
})

karneval = pd.DataFrame({
    'holiday': 'Karneval',
    'ds': pd.to_datetime(['2016-02-04', '2017-02-23', '2018-02-08',
                          '2019-02-28', '2020-02-20', '2021-02-11', '2022-02-24']),
    'lower_window': 0,
    'upper_window': 3,
})

ostern = pd.DataFrame({
  'holiday': 'Ostern',
  'ds': pd.to_datetime(['2016-03-25', '2017-04-14', '2018-03-30',
                        '2019-04-19', '2020-04-10', '2021-04-02', '2022-04-15']),
  'lower_window': 0,
  'upper_window': 3,
})

osterferien = pd.DataFrame({
    'holiday': 'Osterferien',
    'ds': pd.to_datetime(['2016-03-21', '2017-04-06', '2018-03-26',
                          '2019-04-15', '2020-04-06', '2021-03-29', '2022-04-11']),
    'lower_window': 0,
    'upper_window': 13,
})

maifeiertag = pd.DataFrame({
  'holiday': '1. Mai',
  'ds': pd.to_datetime(['2016-05-01', '2017-05-01', '2018-05-01',
                        '2019-05-01', '2020-05-01', '2021-05-01', '2022-05-01']),
  'lower_window': 0,
  'upper_window': 0,
})

christi_himmelfahrt = pd.DataFrame({
  'holiday': 'Christi Himmelfahrt',
  'ds': pd.to_datetime(['2016-05-05', '2017-05-25', '2018-05-10',
                        '2019-05-30', '2020-05-21', '2021-05-13', '2022-05-26']),
  'lower_window': 0,
  'upper_window': 0,
})

vatertag = pd.DataFrame({
    'holiday': 'Vatertag',
    'ds': pd.to_datetime(['2016-05-05', '2017-05-25', '2018-05-10',
                          '2019-05-30', '2020-05-21', '2021-05-13', '2022-05-09']),
    'lower_window': 0,
    'upper_window': 0,
})

muttertag = pd.DataFrame({
    'holiday': 'Muttertag',
    'ds': pd.to_datetime(['2016-05-08', '2017-05-14', '2018-05-13',
                          '2019-05-12', '2020-05-10', '2021-05-09', '2022-05-08']),
    'lower_window': 0,
    'upper_window': 0,
})

pfingsten = pd.DataFrame({
  'holiday': 'Pfingsten',
  'ds': pd.to_datetime(['2016-05-15', '2017-06-04', '2018-05-20',
                        '2019-06-09', '2020-05-31', '2021-05-23', '2022-06-05']),
  'lower_window': 0,
  'upper_window': 1,
})

fronleichnam = pd.DataFrame({
  'holiday': 'Fronleichnam',
  'ds': pd.to_datetime(['2016-05-26', '2017-06-15', '2018-05-31',
                        '2019-06-20', '2020-06-11', '2021-06-03', '2022-06-16']),
  'lower_window': 0,
  'upper_window': 0,
})

sommerferien = pd.DataFrame({
    'holiday': 'Sommerferien',
    'ds': pd.to_datetime(['2016-07-16', '2017-07-15', '2018-07-16',
                          '2019-07-15', '2020-06-29', '2021-07-05', '2022-06-27']),
    'lower_window': 0,
    'upper_window': 45,
})

einheit = pd.DataFrame({
  'holiday': 'Tag der deutschen Einheit',
  'ds': pd.to_datetime(['2016-10-03', '2017-01-01', '2018-01-01',
                        '2019-01-01', '2020-01-01', '2021-01-01', '2022-01-01']),
  'lower_window': 0,
  'upper_window': 0,
})

herbstferien = pd.DataFrame({
    'holiday': 'Herbstferien',
    'ds': pd.to_datetime(['2016-10-10', '2017-10-23', '2018-10-15',
                          '2019-10-14', '2020-10-12', '2021-10-11', '2022-10-04']),
    'lower_window': 0,
    'upper_window': 12,
})

allerheiligen = pd.DataFrame({
  'holiday': 'Allerheiligen',
  'ds': pd.to_datetime(['2016-11-01', '2017-11-01', '2018-11-01',
                        '2019-11-01', '2020-11-01', '2021-11-01', '2022-11-01']),
  'lower_window': 0,
  'upper_window': 0,
})

weihnachten = pd.DataFrame({
  'holiday': 'Weihnachten',
  'ds': pd.to_datetime(['2016-12-25', '2017-12-25', '2018-12-25',
                        '2019-12-25', '2020-12-25', '2021-12-25', '2022-12-25']),
  'lower_window': 0,
  'upper_window': 1,
})

weihnachtsferien = pd.DataFrame({
    'holiday': 'Weihnachtsferien',
    'ds': pd.to_datetime(['2016-12-23', '2017-12-27', '2018-12-21',
                          '2019-12-23', '2020-12-23', '2021-12-23', '2022-12-23']),
    'lower_window': 0,
    'upper_window': 10,
})

# %%
holidays = pd.concat((neujahr, karneval, ostern, osterferien, maifeiertag, christi_himmelfahrt, vatertag, muttertag, 
                      pfingsten, fronleichnam, einheit, herbstferien, allerheiligen, weihnachten, weihnachtsferien))
holidays
# Out:
#              holiday         ds  lower_window  upper_window
# 0            Neujahr 2016-01-01            -1             0
# 1            Neujahr 2017-01-01            -1             0
# 2            Neujahr 2018-01-01            -1             0
# 3            Neujahr 2019-01-01            -1             0
# 4            Neujahr 2020-01-01            -1             0
# ..               ...        ...           ...           ...
# 2   Weihnachtsferien 2018-12-21             0            10
# 3   Weihnachtsferien 2019-12-23             0            10
# 4   Weihnachtsferien 2020-12-23             0            10
# 5   Weihnachtsferien 2021-12-23             0            10
# 6   Weihnachtsferien 2022-12-23             0            10
#
# [105 rows x 4 columns]

# %%
holidays.to_csv('df_feiertage.csv')
